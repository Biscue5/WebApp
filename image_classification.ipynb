# %%
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd

from transformers import pipeline

# %%
img = Image.open('dog.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_classifier = pipeline('image-classification')
preds = image_classifier(img)
preds_df = pd.DataFrame(preds)
preds_df
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 (https://huggingface.co/google/vit-base-patch16-224)
#       score                                           label
# 0  0.792636                                golden retriever
# 1  0.094933                              Labrador retriever
# 2  0.023020                        clumber, clumber spaniel
# 3  0.017037                                  Sussex spaniel
# 4  0.015113  cocker spaniel, English cocker spaniel, cocker
